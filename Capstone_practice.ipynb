# %%
import pandas as pd
import glob

# %%
df_FF = pd.read_csv('Data/Federal_Funds_Rate.csv')
df_FF
# Out:
#            DATE  FEDFUNDS
# 0    1954-07-01      0.80
# 1    1954-08-01      1.22
# 2    1954-09-01      1.07
# 3    1954-10-01      0.85
# 4    1954-11-01      0.83
# ..          ...       ...
# 812  2022-03-01      0.20
# 813  2022-04-01      0.33
# 814  2022-05-01      0.77
# 815  2022-06-01      1.21
# 816  2022-07-01      1.68
#
# [817 rows x 2 columns]

# %%
pd.read_csv('Data/Population_Total.csv')
# Out:
#            DATE    POPTHM
# 0    1959-01-01  175818.0
# 1    1959-02-01  176044.0
# 2    1959-03-01  176274.0
# 3    1959-04-01  176503.0
# 4    1959-05-01  176723.0
# ..          ...       ...
# 757  2022-02-01  332750.0
# 758  2022-03-01  332812.0
# 759  2022-04-01  332863.0
# 760  2022-05-01  332928.0
# 761  2022-06-01  333028.0
#
# [762 rows x 2 columns]

# %%
df_CPI = pd.read_csv('Data/CPI.csv')
df_CPI
# Out:
#            DATE  CPIAUCSL
# 0    1947-01-01    21.480
# 1    1947-02-01    21.620
# 2    1947-03-01    22.000
# 3    1947-04-01    22.000
# 4    1947-05-01    21.950
# ..          ...       ...
# 901  2022-02-01   284.182
# 902  2022-03-01   287.708
# 903  2022-04-01   288.663
# 904  2022-05-01   291.474
# 905  2022-06-01   295.328
#
# [906 rows x 2 columns]

# %%
df = pd.concat(map(pd.read_csv, ['Data/Federal_Funds_Rate.csv', 'Data/10Year_Minus_3M.csv']))
df
# Out:
#            DATE  FEDFUNDS  T10Y3MM
# 0    1954-07-01      0.80      NaN
# 1    1954-08-01      1.22      NaN
# 2    1954-09-01      1.07      NaN
# 3    1954-10-01      0.85      NaN
# 4    1954-11-01      0.83      NaN
# ..          ...       ...      ...
# 482  2022-03-01       NaN     1.68
# 483  2022-04-01       NaN     1.99
# 484  2022-05-01       NaN     1.91
# 485  2022-06-01       NaN     1.60
# 486  2022-07-01       NaN     0.60
#
# [1304 rows x 3 columns]

# %%
df = pd.concat(map(pd.read_csv, ['Data/Federal_Funds_Rate.csv', 'Data/10Year_Minus_3M.csv', 'Data/Average_Hourly_Earnings.csv', 'Data/10Year_Minus_2Year.csv', 'Data/CPI.csv', 'Data/Core_CPI.csv', 'Data/Population_Total.csv', 'Data/10Year_Breakevens.csv']))
df
# Out:
#            DATE  FEDFUNDS  T10Y3MM  T10Y2YM  CPIAUCSL  CPILFESL  POPTHM  \
# 0    1954-07-01      0.80      NaN      NaN       NaN       NaN     NaN
# 1    1954-08-01      1.22      NaN      NaN       NaN       NaN     NaN
# 2    1954-09-01      1.07      NaN      NaN       NaN       NaN     NaN
# 3    1954-10-01      0.85      NaN      NaN       NaN       NaN     NaN
# 4    1954-11-01      0.83      NaN      NaN       NaN       NaN     NaN
# ..          ...       ...      ...      ...       ...       ...     ...
# 230  2022-03-01       NaN      NaN      NaN       NaN       NaN     NaN
# 231  2022-04-01       NaN      NaN      NaN       NaN       NaN     NaN
# 232  2022-05-01       NaN      NaN      NaN       NaN       NaN     NaN
# 233  2022-06-01       NaN      NaN      NaN       NaN       NaN     NaN
# 234  2022-07-01       NaN      NaN      NaN       NaN       NaN     NaN
#
#      T10YIEM
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# ...

# %%
df['POPTHM']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 230   NaN
# 231   NaN
# 232   NaN
# 233   NaN
# 234   NaN
# Name: POPTHM, Length: 4547, dtype: float64

# %%
df = pd.concat(map(pd.read_csv, ['d1.csv', 'd2.csv','d3.csv']))

# %%
files = glob.glob("./Data/*.csv")
dfs = [pd.read_csv(f, header=None) for f in files]

salesdata = pd.concat(dfs, ignore_index=True, axis=1)

# %%
salesdata
# Out:
#               0        1           2        3           4        5   \
# 0           DATE  T10YIEM        DATE  T10Y2YM        DATE  T10Y3MM
# 1     2003-01-01     1.76  1976-06-01     0.80  1982-01-01     1.67
# 2     2003-02-01     1.91  1976-07-01     0.98  1982-02-01     0.15
# 3     2003-03-01     1.87  1976-08-01     1.14  1982-03-01     0.55
# 4     2003-04-01     1.78  1976-09-01     1.17  1982-04-01     0.53
# ...          ...      ...         ...      ...         ...      ...
# 4321         NaN      NaN         NaN      NaN         NaN      NaN
# 4322         NaN      NaN         NaN      NaN         NaN      NaN
# 4323         NaN      NaN         NaN      NaN         NaN      NaN
# 4324         NaN      NaN         NaN      NaN         NaN      NaN
# 4325         NaN      NaN         NaN      NaN         NaN      NaN
#
#               6              7           8        9   ...          44  \
# 0           DATE  CES0500000003        DATE   CC4WSA  ...        DATE
# ...

# %%
files = glob.glob("./Data/*.csv")

# %%
files
# Out:
# ['./Data\\10Year_Breakevens.csv',
#  './Data\\10Year_Minus_2Year.csv',
#  './Data\\10Year_Minus_3M.csv',
#  './Data\\Average_Hourly_Earnings.csv',
#  './Data\\Continuing_Claims_4WeekMA.csv',
#  './Data\\Core_CPI.csv',
#  './Data\\CPI.csv',
#  './Data\\Debt_to_GDP_Quarterly.csv',
#  './Data\\Employment_Cost_Index_ALLCivilians.csv',
#  './Data\\Employment_Cost_Index_PrivInd.csv',
#  './Data\\Federal_Debt_Quarterly.csv',
#  './Data\\Federal_Funds_Rate.csv',
#  './Data\\GDP_Quarterly_Real.csv',
#  './Data\\GDP__Quarterly_Nominal.csv',
#  './Data\\Inital_Claims_4weekMA.csv',
#  './Data\\M1_MoneySupply.csv',
#  './Data\\M2_MoneySupply.csv',
#  './Data\\M2_Money_Velocity_Quarterly.csv',
#  './Data\\Mortgage_Rate_Weekly.csv',
#  './Data\\Nominal_DXY.csv',
#  './Data\\Population_Over55.csv',
#  './Data\\Population_Total.csv',
#  './Data\\Population_WorkingAge.csv',
#  './Data\\PPI_AllCommods.csv',
#  './Data\\UMICH_12M_InflationExpectations.csv',
#  './Data\\UMICH_Consumer_Sentiment.csv',
# ...

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)

# %%
result_2 = pd.concat([df_CPI, df_FF], axis=1).reindex(df_CPI.index)
result_2
# Out:
#            DATE  CPIAUCSL        DATE  FEDFUNDS
# 0    1947-01-01    21.480  1954-07-01      0.80
# 1    1947-02-01    21.620  1954-08-01      1.22
# 2    1947-03-01    22.000  1954-09-01      1.07
# 3    1947-04-01    22.000  1954-10-01      0.85
# 4    1947-05-01    21.950  1954-11-01      0.83
# ..          ...       ...         ...       ...
# 901  2022-02-01   284.182         NaN       NaN
# 902  2022-03-01   287.708         NaN       NaN
# 903  2022-04-01   288.663         NaN       NaN
# 904  2022-05-01   291.474         NaN       NaN
# 905  2022-06-01   295.328         NaN       NaN
#
# [906 rows x 4 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
#####corrrect method?

# %%
df1 = pd.read_csv('Data/CPI.csv')
df1['DATE'] = pd.to_datetime(df1.DATE)

df2 = pd.read_csv("Data/Federal_Funds_Rate.csv")
df2['DATE'] = pd.to_datetime(df2.DATE)


df_all = df2.merge(df1, on='DATE', how='outer')
df_all = result.sort_values('DATE')

df3 = pd.read_csv('Data/GDP_Quarterly_Real.csv')
df3['DATE'] = pd.to_datetime(df3.DATE)
df_all = result.merge(df3, on='DATE', how='outer')
df_all = result.sort_values('DATE')
df_all
# Out:
#           DATE  FEDFUNDS  CPIAUCSL      GDPC1
# 0   1947-01-01       NaN    21.480   2034.450
# 1   1947-02-01       NaN    21.620        NaN
# 2   1947-03-01       NaN    22.000        NaN
# 3   1947-04-01       NaN    22.000   2029.024
# 4   1947-05-01       NaN    21.950        NaN
# 5   1947-06-01       NaN    22.080        NaN
# 6   1947-07-01       NaN    22.230   2024.834
# 7   1947-08-01       NaN    22.400        NaN
# 8   1947-09-01       NaN    22.840        NaN
# 9   1947-10-01       NaN    22.910   2056.508
# 10  1947-11-01       NaN    23.060        NaN
# 11  1947-12-01       NaN    23.410        NaN
# 12  1948-01-01       NaN    23.680   2087.442
# 13  1948-02-01       NaN    23.670        NaN
# 14  1948-03-01       NaN    23.500        NaN
# 15  1948-04-01       NaN    23.820   2121.899
# 16  1948-05-01       NaN    24.010        NaN
# 17  1948-06-01       NaN    24.150        NaN
# 18  1948-07-01       NaN    24.400   2134.056
# ...

# %%
df3 = pd.read_csv('Data/GDP_Quarterly_Real.csv')
df3['DATE'] = pd.to_datetime(df3.DATE)

# %%
result = result.merge(df3, on='DATE', how='outer')
result = result.sort_values('DATE')
result
# Out:
#           DATE  FEDFUNDS  CPIAUCSL      GDPC1
# 0   1947-01-01       NaN    21.480   2034.450
# 1   1947-02-01       NaN    21.620        NaN
# 2   1947-03-01       NaN    22.000        NaN
# 3   1947-04-01       NaN    22.000   2029.024
# 4   1947-05-01       NaN    21.950        NaN
# 5   1947-06-01       NaN    22.080        NaN
# 6   1947-07-01       NaN    22.230   2024.834
# 7   1947-08-01       NaN    22.400        NaN
# 8   1947-09-01       NaN    22.840        NaN
# 9   1947-10-01       NaN    22.910   2056.508
# 10  1947-11-01       NaN    23.060        NaN
# 11  1947-12-01       NaN    23.410        NaN
# 12  1948-01-01       NaN    23.680   2087.442
# 13  1948-02-01       NaN    23.670        NaN
# 14  1948-03-01       NaN    23.500        NaN
# 15  1948-04-01       NaN    23.820   2121.899
# 16  1948-05-01       NaN    24.010        NaN
# 17  1948-06-01       NaN    24.150        NaN
# 18  1948-07-01       NaN    24.400   2134.056
# ...

# %%
df4 = pd.read_csv('Data/M1_MoneySupply.csv')
# Out:
# <ipython-input-119-e436eff30d3d>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df4 = pd.read_csv('Data/M1_MoneySupply.csv', 'Data/M2_Money_Supply.csv')
